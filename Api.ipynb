# %%
from requests import Request, Session
import pandas as pd
import numpy as np
import json
import prettytable as PrettyTable

# %%
# create a pretty table obj
#pretty = PrettyTable()
api_key = '44bd2fb6-dd66-4e64-9d84-58d9591acd61'

# %%
api_url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': api_key,
}

# %%
session = Session()
session.headers.update(headers)

# %%
response = requests.get(api_url,params=parameters, headers=headers)

# %%
response
# Out:
# <Response [200]>

# %%
json_data = response.json()

# %%
json_data
# Out:
# {'status': {'timestamp': '2020-12-22T14:53:38.945Z',
#   'error_code': 0,
#   'error_message': None,
#   'elapsed': 132,
#   'credit_count': 15,
#   'notice': None,
#   'total_count': 4081},
#  'data': [{'id': 1,
#    'name': 'Bitcoin',
#    'symbol': 'BTC',
#    'slug': 'bitcoin',
#    'num_market_pairs': 9711,
#    'date_added': '2013-04-28T00:00:00.000Z',
#    'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channels'],
#    'max_supply': 21000000,
#    'circulating_supply': 18578118,
#    'total_supply': 18578118,
#    'platform': None,
#    'cmc_rank': 1,
#    'last_updated': '2020-12-22T14:52:02.000Z',
#    'quote': {'USD': {'price': 23433.52360928723,
#      'volume_24h': 48558639051.41493,
#      'percent_change_1h': 0.77848709,
#      'percent_change_24h': 3.32375947,
#      'percent_change_7d': 21.4804494,
#      'market_cap': 435350766769.124,
#      'last_updated': '2020-12-22T14:52:02.000Z'}}},
#   {'id': 1027,
#    'name': 'Ethereum',
# ...

# %%
crrypto_data = json_data['data']

# %%
crrypto_data
# Out:
# [{'id': 1,
#   'name': 'Bitcoin',
#   'symbol': 'BTC',
#   'slug': 'bitcoin',
#   'num_market_pairs': 9712,
#   'date_added': '2013-04-28T00:00:00.000Z',
#   'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channels'],
#   'max_supply': 21000000,
#   'circulating_supply': 18578118,
#   'total_supply': 18578118,
#   'platform': None,
#   'cmc_rank': 1,
#   'last_updated': '2020-12-22T14:38:02.000Z',
#   'quote': {'USD': {'price': 23488.86235380458,
#     'volume_24h': 48548467496.93756,
#     'percent_change_1h': 1.53847589,
#     'percent_change_24h': 3.67652664,
#     'percent_change_7d': 21.74541133,
#     'market_cap': 436378856494.7392,
#     'last_updated': '2020-12-22T14:38:02.000Z'}}},
#  {'id': 1027,
#   'name': 'Ethereum',
#   'symbol': 'ETH',
#   'slug': 'ethereum',
#   'num_market_pairs': 5919,
#   'date_added': '2015-08-07T00:00:00.000Z',
#   'tags': ['mineable', 'pow', 'smart-contracts'],
#   'max_supply': None,
#   'circulating_supply': 113937843.3115,
# ...

# %%
for c in crrypto_data:
    name = c['name']
    symbol = c['symbol']
    price = c['quote']['USD']['price']
    market_cap = c['quote']['USD']['market_cap']
    precent_change_1h = c['quote']['USD']['percent_change_1h']
    precent_change_24h = c['quote']['USD']['percent_change_24h']
    precent_change_7d = c['quote']['USD']['percent_change_7d']

# %%
lis = []
for c in crrypto_data:
    name = c['name']
    symbol = c['symbol']
    price = c['quote']['USD']['price']
    market_cap = c['quote']['USD']['market_cap']
    precent_change_1h = c['quote']['USD']['percent_change_1h']
    precent_change_24h = c['quote']['USD']['percent_change_24h']
    precent_change_7d = c['quote']['USD']['percent_change_7d']
    lis.append([name,symbol,price, market_cap,precent_change_1h,precent_change_24h,precent_change_7d])

# %%
print(lis)
# Out:
# [['Bitcoin', 'BTC', 23488.86235380458, 436378856494.7392, 1.53847589, 3.67652664, 21.74541133], ['Ethereum', 'ETH', 617.4175998371156, 70347229748.0037, 0.83879571, 1.26564905, 5.32344802], ['XRP', 'XRP', 0.4918696324462, 22332862878.73354, 0.97394073, -5.68355752, 2.73636959], ['Tether', 'USDT', 0.99975539240272, 20389578467.76416, -0.03388535, 0.0230756, -0.03995493], ['Litecoin', 'LTC', 109.97143230306801, 7273906252.474404, 0.87558754, 3.15637969, 34.41453121], ['Bitcoin Cash', 'BCH', 317.69331285110786, 5909369629.51294, 0.9771355, -1.33036752, 9.67922909], ['Chainlink', 'LINK', 12.46202254367289, 4953773053.611459, 1.22348857, 0.17463706, -1.78745441], ['Cardano', 'ADA', 0.15765518253192, 4905044445.886689, 0.14397564, 4.16763161, 2.26858954], ['Binance Coin', 'BNB', 32.97544855124474, 4761871119.42014, 1.41004066, 2.12214282, 11.0499097], ['Polkadot', 'DOT', 5.03176101864217, 4491279775.09784, -0.08267088, 1.75470491, -1.82167015], ['Stellar', 'XLM', 0.16790480972395, 36696166
# ...

# %%
df = pd.DataFrame(lis)

# %%
df.head()
# Out:
#           0     1             2             3         4         5          6
# 0   Bitcoin   BTC  23488.862354  4.363789e+11  1.538476  3.676527  21.745411
# 1  Ethereum   ETH    617.417600  7.034723e+10  0.838796  1.265649   5.323448
# 2       XRP   XRP      0.491870  2.233286e+10  0.973941 -5.683558   2.736370
# 3    Tether  USDT      0.999755  2.038958e+10 -0.033885  0.023076  -0.039955
# 4  Litecoin   LTC    109.971432  7.273906e+09  0.875588  3.156380  34.414531

# %%
df.columns
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
df.rename({0:'name',1:'symbol',2:'price', 3:'market_cap',4:'precent_change_1h',5:'precent_change_24h',6:'precent_change_7d'}, axis = 1,inplace=True)

# %%
df.head()
# Out:
#        name symbol         price    market_cap  precent_change_1h  \
# 0   Bitcoin    BTC  23488.862354  4.363789e+11           1.538476
# 1  Ethereum    ETH    617.417600  7.034723e+10           0.838796
# 2       XRP    XRP      0.491870  2.233286e+10           0.973941
# 3    Tether   USDT      0.999755  2.038958e+10          -0.033885
# 4  Litecoin    LTC    109.971432  7.273906e+09           0.875588
#
#    precent_change_24h  precent_change_7d
# 0            3.676527          21.745411
# 1            1.265649           5.323448
# 2           -5.683558           2.736370
# 3            0.023076          -0.039955
# 4            3.156380          34.414531

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import chart_studio.plotly as py
import cufflinks as cf
from plotly.offline import iplot, init_notebook_mode
# %matplotlib inline

# %%
df.price.max()
# Out:
# 24734.146041661294

# %%
df['price'].min()
# Out:
# 0.00032085026456

# %%
df.market_cap.max()
# Out:
# 436378856494.7392

# %%
new_url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/price-performance-stats/latest'

# %%
api_new_url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/price-performance-stats/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': api_key,
}

# %%
response1 = requests.get(api_new_url,params=parameters, headers=headers)

# %%
json_data1 = response1.json()

# %%
json_data1
# Out:
# {'status': {'timestamp': '2020-12-24T13:11:26.040Z',
#   'error_code': 1006,
#   'error_message': "Your API Key subscription plan doesn't support this endpoint.",
#   'elapsed': 0,
#   'credit_count': 0}}
